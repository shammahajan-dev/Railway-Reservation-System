# %%
if "gsfgsfa":
    print("Ayega")
else:
    print("Kuch Nahi ayega")
# Out:
# Ayega

# %%
if 0.00:     # False
    print("Zero")
else:
    print("Non Zero")
# Out:
# Non Zero

# %%
if -22:
    print("Ab ye kya hai")
else:
    print("Ye same hai")
# Out:
# Ab ye kya hai

# %%
if None:
    print("None")
else:
    print("Ye galat hai")
# Out:
# Ye galat hai

# %%
if []:
    print("Ye khali hai")
else:
    print("Ye else vala category hai")
# Out:
# Ye else vala category hai

# %% [markdown]
# Task 1: Using AND Operator

# %%
passenger_age = 25
ticket_confirmed = False

if passenger_age==25 and ticket_confirmed:
    print("Passenger Eligible for Travel")

# %%
a=4
if a:
    print("Ye to true hai")
else:
    print("ye else ka part hai")
# Out:
# Ye to true hai

# %% [markdown]
# Task 2: Using OR Operator

# %%
confirmed_seat = False
rac_seat = True
if confirmed_seat or rac_seat:
    print("Reservation Available")
else:
    print("Reservation is not available")
# Out:
# Reservation Available

# %% [markdown]
# Task 3: Using NOT Operator

# %%
ticket_cancelled = False
if not rac_seat and ticket_confirmed:
    print("Ticket is active")
else:
    print('Ticket is expired')
# Out:
# Ticket is expired

# %%
passenger_age = 65
payment_completed = True

if passenger_age >= 60 and payment_completed:
    print("Senior Citizen Reservation Approved")
# Out:
# Senior Citizen Reservation Approved

# %%
if passenger_age=="65" and not payment_completed:
    print("Aap Pagal ho gaye ho")
else:
    print("Mereko chakkar ane lage hai")
# Out:
# Mereko chakkar ane lage hai

# %%
valid_id_proof = True
booking_time_valid = True
if valid_id_proof and booking_time_valid and not payment_completed:
   print("Tatkal Booking Allowed")
else:
   print("Tatkal Booking Denied")
# Out:
# Tatkal Booking Allowed

# %%
passenger_name = "Rahul Sharma"
passenger_age = 30
available_seats = 2
payment_completed = True
ticket_cancelled = False

# %%
if (
   passenger_age >= 18 and
   available_seats > 0 and
   payment_completed and
   not ticket_cancelled
):
   print("===================================")
   print(" Indian Railways Reservation ")
   print("===================================")
   print("Passenger Name :", passenger_name)
   print("Reservation Status : Confirmed")
else:
   print("Reservation Failed")
# Out:
# ===================================
#  Indian Railways Reservation
# ===================================
# Passenger Name : Rahul Sharma
# Reservation Status : Confirmed
