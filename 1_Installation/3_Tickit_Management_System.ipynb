# %% [markdown]
# # LAB 3

# %% [markdown]
# Task 1 : Store Passenger Details Using Variables

# %%
passanger_name = "Rohit Sharma"
passanger_age = 39
gender = 'Male'
Mobile_no = 9867958699

# %%
print("Passenger Name :", passanger_name)
print("Passenger Age :", passanger_age)
print("Gender :", gender)
print("Mobile Number :", Mobile_no)
# Out:
# Passenger Name : Rohit Sharma
# Passenger Age : 39
# Gender : Male
# Mobile Number : 9867958699

# %% [markdown]
# Task 2: Store Ticket Price and Seat Number

# %%
train_name = "Rajdhani Express"
seat_number = "B2-45"
ticket_price = 2450
journey_date = "25-May-2026"

# %%
print("Train Name :", train_name)
print("Seat Number :", seat_number)
print("Ticket Price :", ticket_price)
print("Journey Date :", journey_date)
# Out:
# Train Name : Rajdhani Express
# Seat Number : B2-45
# Ticket Price : 2450
# Journey Date : 25-May-2026

# %%
passanger_name
# Out:
# 'Rohit Sharma'

# %%
# Input Function + Implicit Typecasting
passanger_name = input("Enter your name")
type(passanger_name)
# Out:
# str

# %%
# # Input Function + Explicit Typecasting
ticket_price = int(input("Enter price of tikit"))
print(type(ticket_price))
# Out:
# <class 'int'>

# %%
_=23
print(_)
# Out:
# 23

# %%
id(input("Enter your name"))
# Out:
# 2325699812048

# %%
4
# Out:
# 4

# %% [markdown]
# Task 3: Perform Ticket Fare Calculations

# %%
number_of_passengers = 3
ticket_price = 2450
total_fare = number_of_passengers * ticket_price
print("Total Fare :", total_fare)
# Out:
# Total Fare : 7350

# %% [markdown]
# Task 4: Calculate GST on Ticket Fare

# %%
gst_percentage = 5
gst_amount = (total_fare * gst_percentage) / 100
print("GST Amount :", gst_amount)
final_amount = total_fare + gst_amount
print("Final Payable Amount :", final_amount)
# Out:
# GST Amount : 367.5
# Final Payable Amount : 7717.5

# %% [markdown]
# Task 5: Display Complete Railway Ticket Information

# %%
print("----------- Indian Railways Ticket -----------")
print("Passenger Name :", passanger_name)
print("Train Name 	:", train_name)
print("Seat Number	:", seat_number)
print("Journey Date   :", journey_date)
print("Passengers 	:", number_of_passengers)
print("Ticket Fare	:", total_fare)
print("GST Amount 	:", gst_amount)
print("Final Amount   :", final_amount)
print("----------------------------------------------")
# Out:
# ----------- Indian Railways Ticket -----------
# Passenger Name : True
# Train Name 	: Rajdhani Express
# Seat Number	: B2-45
# Journey Date   : 25-May-2026
# Passengers 	: 3
# Ticket Fare	: 7350
# GST Amount 	: 367.5
# Final Amount   : 7717.5
# ----------------------------------------------
